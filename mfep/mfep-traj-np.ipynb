# %%
import sys
import numpy as np
import pandas as pd

# %% [markdown]
# ### Extract MFEP trajectory using MFEP profile ("mfep-profile-np.dat" generated using "mfep-profile-np.ipynb") and COLVAR file produced at the end of metadynamics simulations

# %% [markdown]
# From the COLVAR file produced the end of the metadynamics simulations, throw away header lines (start with #!) and read columns corresponding to time, s(R) and z(R)

# %%
# %%bash
# awk '$1!="#!" {print $1,$2,$3}' COLVAR > time_cvs.dat

# %%
time_cvs=pd.read_csv("time_cv.dat",header=None,sep="\s+",usecols=[i for i in range(3)])
time_cvs.columns = ["time","s(R)", f"z(R)"]

# %% [markdown]
# Convert z(R) from nm$^2$ to Å$^2$ and round of time, s(R) and z(R) values

# %%
s = np.array(time_cvs["s(R)"]).reshape(-1,1)
time_cvs["time"]=(time_cvs["time"]).astype(int)
time_cvs["z(R)"]=(time_cvs["z(R)"]*100).round(1)
time_cvs["s(R)"]=time_cvs["s(R)"].round(1)

# %% [markdown]
# Read the "mfep-profile-np.dat" file generated using "mfep-profile-np.ipynb" and store s(R) and z(R) values into s and z numpy arrays

# %%
gprofile=pd.read_csv("mfep-profile-np.dat",header=0,sep="\s+",usecols=[i for i in range(3)])
gprofile.index=[i for i in range(1,26)]
gprofile["s(R)"]=gprofile["s(R)"].round(1)
s=np.array(gprofile["s(R)"])
z=np.array(gprofile["z(R)"])

# %% [markdown]
# For each MFEP (s,z) bin, scan through the "time_cvs" dataframe to extract a smaller dataframe at which the corresponding (s,z) value occurs. Some deviation is allowed in s (sdev) and z (zdev) values in the scanning process to achieve sufficient sampling. The extracted dataframes are first appended in a list. Then times are extracted from each dataframe and are written to "time{i}.dat" where "i" is the bin index

# %%
list1=[]
sdev=0.1
zdev=0.05
for (i,j) in zip(s,z):
        k=i-sdev
        l=i+sdev
        m=j-zdev
        n=j+zdev
        x=time_cvs[(time_cvs["s(R)"]>=k) & (time_cvs["s(R)"]<=l) & (time_cvs["z(R)"]>=m) & (time_cvs["z(R)"]<=n)]
        list1.append(x)
for i in range(1,len(list1)+1):
    list1[i-1]["time"].to_csv(f"time{i}.txt",index=None)

# %% [markdown]
# Now, extracted times from each bin are read, and within each bin one of the times is arbitrarily chosen and corresponding pdb file is extracted from gmx trajectory

# %%
# %%bash
# for i in {1..25}
# do
#     tail -1 time$i.txt | awk '{printf "%1.0f\n",$1}'
# done > time_final.txt
#
# for i in {1..25}
# do
#  rm $i.pdb
#  echo 1 | gmx trjconv -s abl1_md.tpr -f abl1_md-fit.xtc -o $i.pdb -dump $(awk -v var="$i" 'NR==var{print}' time_final.txt)
# done
# Out:
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Select group for output
# Selected 1: 'Protein'
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Select group for output
# Selected 1: 'Protein'
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Select group for output
# Selected 1: 'Protein'
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Select group for output
# Selected 1: 'Protein'
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Select group for output
# Selected 1: 'Protein'
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Select group for output
# Selected 1: 'Protein'
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Select group for output
# Selected 1: 'Protein'
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Select group for output
# Selected 1: 'Protein'
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Select group for output
# Selected 1: 'Protein'
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Select group for output
# Selected 1: 'Protein'
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Select group for output
# Selected 1: 'Protein'
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Select group for output
# Selected 1: 'Protein'
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Select group for output
# Selected 1: 'Protein'
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Select group for output
# Selected 1: 'Protein'
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Select group for output
# Selected 1: 'Protein'
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Select group for output
# Selected 1: 'Protein'
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Select group for output
# Selected 1: 'Protein'
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Select group for output
# Selected 1: 'Protein'
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Select group for output
# Selected 1: 'Protein'
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Select group for output
# Selected 1: 'Protein'
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Select group for output
# Selected 1: 'Protein'
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Select group for output
# Selected 1: 'Protein'
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Select group for output
# Selected 1: 'Protein'
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Select group for output
# Selected 1: 'Protein'
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Select group for output
# Selected 1: 'Protein'
#              :-) GROMACS - gmx trjconv, 2020.1-Ubuntu-2020.1-1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx trjconv, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /home/baoraa/manuscript/results/3_mtd/2D-profiles/non-phos/3
# Command line:
#   gmx trjconv -s abl1_md.tpr -f abl1_md-fit.xtc -o 1.pdb -dump 21047
#
# Will write pdb: Protein data bank file
# Reading file abl1_md.tpr, VERSION 2018.6 (single precision)
# Reading file abl1_md.tpr, VERSION 2018.6 (single precision)
# Group     0 (         System) has 67927 elements
# Group     1 (        Protein) has  4249 elements
# Group     2 (      Protein-H) has  2144 elements
# Group     3 (        C-alpha) has   263 elements
# Group     4 (       Backbone) has   789 elements
# Group     5 (      MainChain) has  1051 elements
# Group     6 (   MainChain+Cb) has  1299 elements
# Group     7 (    MainChain+H) has  1305 elements
# Group     8 (      SideChain) has  2944 elements
# Group     9 (    SideChain-H) has  1093 elements
# Group    10 (    Prot-Masses) has  4249 elements
# Group    11 (    non-Protein) has 63678 elements
# Group    12 (          Water) has 63546 elements
# Group    13 (            SOL) has 63546 elements
# Group    14 (      non-Water) has  4381 elements
# Group    15 (            Ion) has   132 elements
# Group    16 (              K) has    70 elements
# Group    17 (             CL) has    62 elements
# Group    18 ( Water_and_ions) has 63678 elements
# Reading frame       0 time    0.000
# Precision of abl1_md-fit.xtc is 0.001 (nm)
# Reading frame    3000 time 18000.000
# Dumping frame at t= 21048 ps
#  ->  frame      0 time 21048.000
#
# GROMACS reminds you: "Erwin with his psi can do / Calculations quite a few. / But one thing has not been seen / Just what psi really mean." (Felix Bloch)
#
#              :-) GROMACS - gmx trjconv, 2020.1-Ubuntu-2020.1-1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx trjconv, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /home/baoraa/manuscript/results/3_mtd/2D-profiles/non-phos/3
# Command line:
#   gmx trjconv -s abl1_md.tpr -f abl1_md-fit.xtc -o 2.pdb -dump 20576
#
# Will write pdb: Protein data bank file
# Reading file abl1_md.tpr, VERSION 2018.6 (single precision)
# Reading file abl1_md.tpr, VERSION 2018.6 (single precision)
# Group     0 (         System) has 67927 elements
# Group     1 (        Protein) has  4249 elements
# Group     2 (      Protein-H) has  2144 elements
# Group     3 (        C-alpha) has   263 elements
# Group     4 (       Backbone) has   789 elements
# Group     5 (      MainChain) has  1051 elements
# Group     6 (   MainChain+Cb) has  1299 elements
# Group     7 (    MainChain+H) has  1305 elements
# Group     8 (      SideChain) has  2944 elements
# Group     9 (    SideChain-H) has  1093 elements
# Group    10 (    Prot-Masses) has  4249 elements
# Group    11 (    non-Protein) has 63678 elements
# Group    12 (          Water) has 63546 elements
# Group    13 (            SOL) has 63546 elements
# Group    14 (      non-Water) has  4381 elements
# Group    15 (            Ion) has   132 elements
# Group    16 (              K) has    70 elements
# Group    17 (             CL) has    62 elements
# Group    18 ( Water_and_ions) has 63678 elements
# Reading frame       0 time    0.000
# Precision of abl1_md-fit.xtc is 0.001 (nm)
# Reading frame    3000 time 18000.000
# Dumping frame at t= 20574 ps
#  ->  frame      0 time 20574.000
#
# GROMACS reminds you: "What If None Of Your Dreams Come True ?" (E. Costello)
#
#              :-) GROMACS - gmx trjconv, 2020.1-Ubuntu-2020.1-1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx trjconv, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /home/baoraa/manuscript/results/3_mtd/2D-profiles/non-phos/3
# Command line:
#   gmx trjconv -s abl1_md.tpr -f abl1_md-fit.xtc -o 3.pdb -dump 23500
#
# Will write pdb: Protein data bank file
# Reading file abl1_md.tpr, VERSION 2018.6 (single precision)
# Reading file abl1_md.tpr, VERSION 2018.6 (single precision)
# Group     0 (         System) has 67927 elements
# Group     1 (        Protein) has  4249 elements
# Group     2 (      Protein-H) has  2144 elements
# Group     3 (        C-alpha) has   263 elements
# Group     4 (       Backbone) has   789 elements
# Group     5 (      MainChain) has  1051 elements
# Group     6 (   MainChain+Cb) has  1299 elements
# Group     7 (    MainChain+H) has  1305 elements
# Group     8 (      SideChain) has  2944 elements
# Group     9 (    SideChain-H) has  1093 elements
# Group    10 (    Prot-Masses) has  4249 elements
# Group    11 (    non-Protein) has 63678 elements
# Group    12 (          Water) has 63546 elements
# Group    13 (            SOL) has 63546 elements
# Group    14 (      non-Water) has  4381 elements
# Group    15 (            Ion) has   132 elements
# Group    16 (              K) has    70 elements
# Group    17 (             CL) has    62 elements
# Group    18 ( Water_and_ions) has 63678 elements
# Reading frame       0 time    0.000
# Precision of abl1_md-fit.xtc is 0.001 (nm)
# Reading frame    3000 time 18000.000
# Dumping frame at t= 23502 ps
#  ->  frame      0 time 23502.000
#
# GROMACS reminds you: "Misslycka kan man med all kod" (Mats Nylen)
#
#              :-) GROMACS - gmx trjconv, 2020.1-Ubuntu-2020.1-1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx trjconv, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /home/baoraa/manuscript/results/3_mtd/2D-profiles/non-phos/3
# Command line:
#   gmx trjconv -s abl1_md.tpr -f abl1_md-fit.xtc -o 4.pdb -dump 31871
#
# Will write pdb: Protein data bank file
# Reading file abl1_md.tpr, VERSION 2018.6 (single precision)
# Reading file abl1_md.tpr, VERSION 2018.6 (single precision)
# Group     0 (         System) has 67927 elements
# Group     1 (        Protein) has  4249 elements
# Group     2 (      Protein-H) has  2144 elements
# Group     3 (        C-alpha) has   263 elements
# Group     4 (       Backbone) has   789 elements
# Group     5 (      MainChain) has  1051 elements
# Group     6 (   MainChain+Cb) has  1299 elements
# Group     7 (    MainChain+H) has  1305 elements
# Group     8 (      SideChain) has  2944 elements
# Group     9 (    SideChain-H) has  1093 elements
# Group    10 (    Prot-Masses) has  4249 elements
# Group    11 (    non-Protein) has 63678 elements
# Group    12 (          Water) has 63546 elements
# Group    13 (            SOL) has 63546 elements
# Group    14 (      non-Water) has  4381 elements
# Group    15 (            Ion) has   132 elements
# Group    16 (              K) has    70 elements
# Group    17 (             CL) has    62 elements
# Group    18 ( Water_and_ions) has 63678 elements
# Reading frame       0 time    0.000
# Precision of abl1_md-fit.xtc is 0.001 (nm)
# Reading frame    5000 time 30000.000
# Dumping frame at t= 31872 ps
#  ->  frame      0 time 31872.000
#
# GROMACS reminds you: "Misslycka kan man med all kod" (Mats Nylen)
#
#              :-) GROMACS - gmx trjconv, 2020.1-Ubuntu-2020.1-1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx trjconv, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /home/baoraa/manuscript/results/3_mtd/2D-profiles/non-phos/3
# Command line:
#   gmx trjconv -s abl1_md.tpr -f abl1_md-fit.xtc -o 5.pdb -dump 31946
#
# Will write pdb: Protein data bank file
# Reading file abl1_md.tpr, VERSION 2018.6 (single precision)
# Reading file abl1_md.tpr, VERSION 2018.6 (single precision)
# Group     0 (         System) has 67927 elements
# Group     1 (        Protein) has  4249 elements
# Group     2 (      Protein-H) has  2144 elements
# Group     3 (        C-alpha) has   263 elements
# Group     4 (       Backbone) has   789 elements
# Group     5 (      MainChain) has  1051 elements
# Group     6 (   MainChain+Cb) has  1299 elements
# Group     7 (    MainChain+H) has  1305 elements
# Group     8 (      SideChain) has  2944 elements
# Group     9 (    SideChain-H) has  1093 elements
# Group    10 (    Prot-Masses) has  4249 elements
# Group    11 (    non-Protein) has 63678 elements
# Group    12 (          Water) has 63546 elements
# Group    13 (            SOL) has 63546 elements
# Group    14 (      non-Water) has  4381 elements
# Group    15 (            Ion) has   132 elements
# Group    16 (              K) has    70 elements
# Group    17 (             CL) has    62 elements
# Group    18 ( Water_and_ions) has 63678 elements
# Reading frame       0 time    0.000
# Precision of abl1_md-fit.xtc is 0.001 (nm)
# Reading frame    5000 time 30000.000
# Dumping frame at t= 31944 ps
#  ->  frame      0 time 31944.000
#
# GROMACS reminds you: "I Was Born to Have Adventure" (F. Zappa)
#
#              :-) GROMACS - gmx trjconv, 2020.1-Ubuntu-2020.1-1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx trjconv, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /home/baoraa/manuscript/results/3_mtd/2D-profiles/non-phos/3
# Command line:
#   gmx trjconv -s abl1_md.tpr -f abl1_md-fit.xtc -o 6.pdb -dump 29945
#
# Will write pdb: Protein data bank file
# Reading file abl1_md.tpr, VERSION 2018.6 (single precision)
# Reading file abl1_md.tpr, VERSION 2018.6 (single precision)
# Group     0 (         System) has 67927 elements
# Group     1 (        Protein) has  4249 elements
# Group     2 (      Protein-H) has  2144 elements
# Group     3 (        C-alpha) has   263 elements
# Group     4 (       Backbone) has   789 elements
# Group     5 (      MainChain) has  1051 elements
# Group     6 (   MainChain+Cb) has  1299 elements
# Group     7 (    MainChain+H) has  1305 elements
# Group     8 (      SideChain) has  2944 elements
# Group     9 (    SideChain-H) has  1093 elements
# Group    10 (    Prot-Masses) has  4249 elements
# Group    11 (    non-Protein) has 63678 elements
# Group    12 (          Water) has 63546 elements
# Group    13 (            SOL) has 63546 elements
# Group    14 (      non-Water) has  4381 elements
# Group    15 (            Ion) has   132 elements
# Group    16 (              K) has    70 elements
# Group    17 (             CL) has    62 elements
# Group    18 ( Water_and_ions) has 63678 elements
# Reading frame       0 time    0.000
# Precision of abl1_md-fit.xtc is 0.001 (nm)
# Reading frame    4000 time 24000.000
# Dumping frame at t= 29946 ps
#  ->  frame      0 time 29946.000
#
# GROMACS reminds you: "History has expired" (PubMed Central)
#
#              :-) GROMACS - gmx trjconv, 2020.1-Ubuntu-2020.1-1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx trjconv, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /home/baoraa/manuscript/results/3_mtd/2D-profiles/non-phos/3
# Command line:
#   gmx trjconv -s abl1_md.tpr -f abl1_md-fit.xtc -o 7.pdb -dump 6654
#
# Will write pdb: Protein data bank file
# Reading file abl1_md.tpr, VERSION 2018.6 (single precision)
# Reading file abl1_md.tpr, VERSION 2018.6 (single precision)
# Group     0 (         System) has 67927 elements
# Group     1 (        Protein) has  4249 elements
# Group     2 (      Protein-H) has  2144 elements
# Group     3 (        C-alpha) has   263 elements
# Group     4 (       Backbone) has   789 elements
# Group     5 (      MainChain) has  1051 elements
# Group     6 (   MainChain+Cb) has  1299 elements
# Group     7 (    MainChain+H) has  1305 elements
# Group     8 (      SideChain) has  2944 elements
# Group     9 (    SideChain-H) has  1093 elements
# Group    10 (    Prot-Masses) has  4249 elements
# Group    11 (    non-Protein) has 63678 elements
# Group    12 (          Water) has 63546 elements
# Group    13 (            SOL) has 63546 elements
# Group    14 (      non-Water) has  4381 elements
# Group    15 (            Ion) has   132 elements
# Group    16 (              K) has    70 elements
# Group    17 (             CL) has    62 elements
# Group    18 ( Water_and_ions) has 63678 elements
# Reading frame       0 time    0.000
# Precision of abl1_md-fit.xtc is 0.001 (nm)
# Reading frame    1100 time 6600.000
# Dumping frame at t= 6654 ps
#  ->  frame      0 time 6654.000
#
# GROMACS reminds you: "A mathematician is a blind man in a dark room looking for a black cat which isn't there." (Charles Darwin)
#
#              :-) GROMACS - gmx trjconv, 2020.1-Ubuntu-2020.1-1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx trjconv, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /home/baoraa/manuscript/results/3_mtd/2D-profiles/non-phos/3
# Command line:
#   gmx trjconv -s abl1_md.tpr -f abl1_md-fit.xtc -o 8.pdb -dump 31102
#
# Will write pdb: Protein data bank file
# Reading file abl1_md.tpr, VERSION 2018.6 (single precision)
# Reading file abl1_md.tpr, VERSION 2018.6 (single precision)
# Group     0 (         System) has 67927 elements
# Group     1 (        Protein) has  4249 elements
# Group     2 (      Protein-H) has  2144 elements
# Group     3 (        C-alpha) has   263 elements
# Group     4 (       Backbone) has   789 elements
# Group     5 (      MainChain) has  1051 elements
# Group     6 (   MainChain+Cb) has  1299 elements
# Group     7 (    MainChain+H) has  1305 elements
# Group     8 (      SideChain) has  2944 elements
# Group     9 (    SideChain-H) has  1093 elements
# Group    10 (    Prot-Masses) has  4249 elements
# Group    11 (    non-Protein) has 63678 elements
# Group    12 (          Water) has 63546 elements
# Group    13 (            SOL) has 63546 elements
# Group    14 (      non-Water) has  4381 elements
# Group    15 (            Ion) has   132 elements
# Group    16 (              K) has    70 elements
# Group    17 (             CL) has    62 elements
# Group    18 ( Water_and_ions) has 63678 elements
# Reading frame       0 time    0.000
# Precision of abl1_md-fit.xtc is 0.001 (nm)
# Reading frame    5000 time 30000.000
# Dumping frame at t= 31104 ps
#  ->  frame      0 time 31104.000
#
# GROMACS reminds you: "It is disconcerting to reflect on the number of students we have flunked in chemistry for not knowing what we later found to be untrue." (Robert L. Weber)
#
#              :-) GROMACS - gmx trjconv, 2020.1-Ubuntu-2020.1-1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx trjconv, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /home/baoraa/manuscript/results/3_mtd/2D-profiles/non-phos/3
# Command line:
#   gmx trjconv -s abl1_md.tpr -f abl1_md-fit.xtc -o 9.pdb -dump 33692
#
# Will write pdb: Protein data bank file
# Reading file abl1_md.tpr, VERSION 2018.6 (single precision)
# Reading file abl1_md.tpr, VERSION 2018.6 (single precision)
# Group     0 (         System) has 67927 elements
# Group     1 (        Protein) has  4249 elements
# Group     2 (      Protein-H) has  2144 elements
# Group     3 (        C-alpha) has   263 elements
# Group     4 (       Backbone) has   789 elements
# Group     5 (      MainChain) has  1051 elements
# Group     6 (   MainChain+Cb) has  1299 elements
# Group     7 (    MainChain+H) has  1305 elements
# Group     8 (      SideChain) has  2944 elements
# Group     9 (    SideChain-H) has  1093 elements
# Group    10 (    Prot-Masses) has  4249 elements
# Group    11 (    non-Protein) has 63678 elements
# Group    12 (          Water) has 63546 elements
# Group    13 (            SOL) has 63546 elements
# Group    14 (      non-Water) has  4381 elements
# Group    15 (            Ion) has   132 elements
# Group    16 (              K) has    70 elements
# Group    17 (             CL) has    62 elements
# Group    18 ( Water_and_ions) has 63678 elements
# Reading frame       0 time    0.000
# Precision of abl1_md-fit.xtc is 0.001 (nm)
# Reading frame    5000 time 30000.000
# Dumping frame at t= 33690 ps
#  ->  frame      0 time 33690.000
#
# GROMACS reminds you: "Yeah, uh uh, Neil's Head !" (Neil)
#
#              :-) GROMACS - gmx trjconv, 2020.1-Ubuntu-2020.1-1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx trjconv, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /home/baoraa/manuscript/results/3_mtd/2D-profiles/non-phos/3
# Command line:
#   gmx trjconv -s abl1_md.tpr -f abl1_md-fit.xtc -o 10.pdb -dump 33089
#
# Will write pdb: Protein data bank file
# Reading file abl1_md.tpr, VERSION 2018.6 (single precision)
# Reading file abl1_md.tpr, VERSION 2018.6 (single precision)
# Group     0 (         System) has 67927 elements
# Group     1 (        Protein) has  4249 elements
# Group     2 (      Protein-H) has  2144 elements
# Group     3 (        C-alpha) has   263 elements
# Group     4 (       Backbone) has   789 elements
# Group     5 (      MainChain) has  1051 elements
# Group     6 (   MainChain+Cb) has  1299 elements
# Group     7 (    MainChain+H) has  1305 elements
# Group     8 (      SideChain) has  2944 elements
# Group     9 (    SideChain-H) has  1093 elements
# Group    10 (    Prot-Masses) has  4249 elements
# Group    11 (    non-Protein) has 63678 elements
# Group    12 (          Water) has 63546 elements
# Group    13 (            SOL) has 63546 elements
# Group    14 (      non-Water) has  4381 elements
# Group    15 (            Ion) has   132 elements
# Group    16 (              K) has    70 elements
# Group    17 (             CL) has    62 elements
# Group    18 ( Water_and_ions) has 63678 elements
# Reading frame       0 time    0.000
# Precision of abl1_md-fit.xtc is 0.001 (nm)
# Reading frame    5000 time 30000.000
# Dumping frame at t= 33090 ps
#  ->  frame      0 time 33090.000
#
# GROMACS reminds you: "If I Wanted You to Understand This, I Would Explain it Better" (J. Cruijff)
#
#              :-) GROMACS - gmx trjconv, 2020.1-Ubuntu-2020.1-1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx trjconv, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /home/baoraa/manuscript/results/3_mtd/2D-profiles/non-phos/3
# Command line:
#   gmx trjconv -s abl1_md.tpr -f abl1_md-fit.xtc -o 11.pdb -dump 34093
#
# Will write pdb: Protein data bank file
# Reading file abl1_md.tpr, VERSION 2018.6 (single precision)
# Reading file abl1_md.tpr, VERSION 2018.6 (single precision)
# Group     0 (         System) has 67927 elements
# Group     1 (        Protein) has  4249 elements
# Group     2 (      Protein-H) has  2144 elements
# Group     3 (        C-alpha) has   263 elements
# Group     4 (       Backbone) has   789 elements
# Group     5 (      MainChain) has  1051 elements
# Group     6 (   MainChain+Cb) has  1299 elements
# Group     7 (    MainChain+H) has  1305 elements
# Group     8 (      SideChain) has  2944 elements
# Group     9 (    SideChain-H) has  1093 elements
# Group    10 (    Prot-Masses) has  4249 elements
# Group    11 (    non-Protein) has 63678 elements
# Group    12 (          Water) has 63546 elements
# Group    13 (            SOL) has 63546 elements
# Group    14 (      non-Water) has  4381 elements
# Group    15 (            Ion) has   132 elements
# Group    16 (              K) has    70 elements
# Group    17 (             CL) has    62 elements
# Group    18 ( Water_and_ions) has 63678 elements
# Reading frame       0 time    0.000
# Precision of abl1_md-fit.xtc is 0.001 (nm)
# Reading frame    5000 time 30000.000
# Dumping frame at t= 34092 ps
#  ->  frame      0 time 34092.000
#
# GROMACS reminds you: "Science... never solves a problem without creating ten more." (George Bernard Shaw)
#
#              :-) GROMACS - gmx trjconv, 2020.1-Ubuntu-2020.1-1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx trjconv, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /home/baoraa/manuscript/results/3_mtd/2D-profiles/non-phos/3
# Command line:
#   gmx trjconv -s abl1_md.tpr -f abl1_md-fit.xtc -o 12.pdb -dump 69379
#
# Will write pdb: Protein data bank file
# Reading file abl1_md.tpr, VERSION 2018.6 (single precision)
# Reading file abl1_md.tpr, VERSION 2018.6 (single precision)
# Group     0 (         System) has 67927 elements
# Group     1 (        Protein) has  4249 elements
# Group     2 (      Protein-H) has  2144 elements
# Group     3 (        C-alpha) has   263 elements
# Group     4 (       Backbone) has   789 elements
# Group     5 (      MainChain) has  1051 elements
# Group     6 (   MainChain+Cb) has  1299 elements
# Group     7 (    MainChain+H) has  1305 elements
# Group     8 (      SideChain) has  2944 elements
# Group     9 (    SideChain-H) has  1093 elements
# Group    10 (    Prot-Masses) has  4249 elements
# Group    11 (    non-Protein) has 63678 elements
# Group    12 (          Water) has 63546 elements
# Group    13 (            SOL) has 63546 elements
# Group    14 (      non-Water) has  4381 elements
# Group    15 (            Ion) has   132 elements
# Group    16 (              K) has    70 elements
# Group    17 (             CL) has    62 elements
# Group    18 ( Water_and_ions) has 63678 elements
# Reading frame       0 time    0.000
# Precision of abl1_md-fit.xtc is 0.001 (nm)
# Reading frame   11000 time 66000.000
# Dumping frame at t= 69378 ps
#  ->  frame      0 time 69378.000
#
# GROMACS reminds you: "I think it's very important to get more women into computing. My slogan is: Computing is too important to be left to men." (Karen Jones)
#
#              :-) GROMACS - gmx trjconv, 2020.1-Ubuntu-2020.1-1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx trjconv, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /home/baoraa/manuscript/results/3_mtd/2D-profiles/non-phos/3
# Command line:
#   gmx trjconv -s abl1_md.tpr -f abl1_md-fit.xtc -o 13.pdb -dump 70368
#
# Will write pdb: Protein data bank file
# Reading file abl1_md.tpr, VERSION 2018.6 (single precision)
# Reading file abl1_md.tpr, VERSION 2018.6 (single precision)
# Group     0 (         System) has 67927 elements
# Group     1 (        Protein) has  4249 elements
# Group     2 (      Protein-H) has  2144 elements
# Group     3 (        C-alpha) has   263 elements
# Group     4 (       Backbone) has   789 elements
# Group     5 (      MainChain) has  1051 elements
# Group     6 (   MainChain+Cb) has  1299 elements
# Group     7 (    MainChain+H) has  1305 elements
# Group     8 (      SideChain) has  2944 elements
# Group     9 (    SideChain-H) has  1093 elements
# Group    10 (    Prot-Masses) has  4249 elements
# Group    11 (    non-Protein) has 63678 elements
# Group    12 (          Water) has 63546 elements
# Group    13 (            SOL) has 63546 elements
# Group    14 (      non-Water) has  4381 elements
# Group    15 (            Ion) has   132 elements
# Group    16 (              K) has    70 elements
# Group    17 (             CL) has    62 elements
# Group    18 ( Water_and_ions) has 63678 elements
# Reading frame       0 time    0.000
# Precision of abl1_md-fit.xtc is 0.001 (nm)
# Reading frame   11000 time 66000.000
# Dumping frame at t= 70368 ps
#  ->  frame      0 time 70368.000
#
# GROMACS reminds you: "Life would be tragic if it weren't funny." (Stephen Hawking)
#
#              :-) GROMACS - gmx trjconv, 2020.1-Ubuntu-2020.1-1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx trjconv, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /home/baoraa/manuscript/results/3_mtd/2D-profiles/non-phos/3
# Command line:
#   gmx trjconv -s abl1_md.tpr -f abl1_md-fit.xtc -o 14.pdb -dump 69303
#
# Will write pdb: Protein data bank file
# Reading file abl1_md.tpr, VERSION 2018.6 (single precision)
# Reading file abl1_md.tpr, VERSION 2018.6 (single precision)
# Group     0 (         System) has 67927 elements
# Group     1 (        Protein) has  4249 elements
# Group     2 (      Protein-H) has  2144 elements
# Group     3 (        C-alpha) has   263 elements
# Group     4 (       Backbone) has   789 elements
# Group     5 (      MainChain) has  1051 elements
# Group     6 (   MainChain+Cb) has  1299 elements
# Group     7 (    MainChain+H) has  1305 elements
# Group     8 (      SideChain) has  2944 elements
# Group     9 (    SideChain-H) has  1093 elements
# ...
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx trjconv, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /home/baoraa/manuscript/results/3_mtd/2D-profiles/non-phos/3
# Command line:
#   gmx trjconv -s abl1_md.tpr -f abl1_md-fit.xtc -o 21.pdb -dump 57137
#
# Will write pdb: Protein data bank file
# Reading file abl1_md.tpr, VERSION 2018.6 (single precision)
# Reading file abl1_md.tpr, VERSION 2018.6 (single precision)
# Group     0 (         System) has 67927 elements
# Group     1 (        Protein) has  4249 elements
# Group     2 (      Protein-H) has  2144 elements
# Group     3 (        C-alpha) has   263 elements
# Group     4 (       Backbone) has   789 elements
# Group     5 (      MainChain) has  1051 elements
# Group     6 (   MainChain+Cb) has  1299 elements
# Group     7 (    MainChain+H) has  1305 elements
# Group     8 (      SideChain) has  2944 elements
# Group     9 (    SideChain-H) has  1093 elements
# Group    10 (    Prot-Masses) has  4249 elements
# Group    11 (    non-Protein) has 63678 elements
# Group    12 (          Water) has 63546 elements
# Group    13 (            SOL) has 63546 elements
# Group    14 (      non-Water) has  4381 elements
# Group    15 (            Ion) has   132 elements
# Group    16 (              K) has    70 elements
# Group    17 (             CL) has    62 elements
# Group    18 ( Water_and_ions) has 63678 elements
# Reading frame       0 time    0.000
# Precision of abl1_md-fit.xtc is 0.001 (nm)
# Reading frame    9000 time 54000.000
# Dumping frame at t= 57138 ps
#  ->  frame      0 time 57138.000
#
# GROMACS reminds you: "The Nobel Prize is fine, but the drugs I've developed are rewards in themselves." (Gertrude Elion)
#
#              :-) GROMACS - gmx trjconv, 2020.1-Ubuntu-2020.1-1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx trjconv, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /home/baoraa/manuscript/results/3_mtd/2D-profiles/non-phos/3
# Command line:
#   gmx trjconv -s abl1_md.tpr -f abl1_md-fit.xtc -o 22.pdb -dump 57621
#
# Will write pdb: Protein data bank file
# Reading file abl1_md.tpr, VERSION 2018.6 (single precision)
# Reading file abl1_md.tpr, VERSION 2018.6 (single precision)
# Group     0 (         System) has 67927 elements
# Group     1 (        Protein) has  4249 elements
# Group     2 (      Protein-H) has  2144 elements
# Group     3 (        C-alpha) has   263 elements
# Group     4 (       Backbone) has   789 elements
# Group     5 (      MainChain) has  1051 elements
# Group     6 (   MainChain+Cb) has  1299 elements
# Group     7 (    MainChain+H) has  1305 elements
# Group     8 (      SideChain) has  2944 elements
# Group     9 (    SideChain-H) has  1093 elements
# Group    10 (    Prot-Masses) has  4249 elements
# Group    11 (    non-Protein) has 63678 elements
# Group    12 (          Water) has 63546 elements
# Group    13 (            SOL) has 63546 elements
# Group    14 (      non-Water) has  4381 elements
# Group    15 (            Ion) has   132 elements
# Group    16 (              K) has    70 elements
# Group    17 (             CL) has    62 elements
# Group    18 ( Water_and_ions) has 63678 elements
# Reading frame       0 time    0.000
# Precision of abl1_md-fit.xtc is 0.001 (nm)
# Reading frame    9000 time 54000.000
# Dumping frame at t= 57624 ps
#  ->  frame      0 time 57624.000
#
# GROMACS reminds you: "Though the path of the comet is sure, it's constitution is not" (Peter Hammill)
#
#              :-) GROMACS - gmx trjconv, 2020.1-Ubuntu-2020.1-1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx trjconv, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /home/baoraa/manuscript/results/3_mtd/2D-profiles/non-phos/3
# Command line:
#   gmx trjconv -s abl1_md.tpr -f abl1_md-fit.xtc -o 23.pdb -dump 57581
#
# Will write pdb: Protein data bank file
# Reading file abl1_md.tpr, VERSION 2018.6 (single precision)
# Reading file abl1_md.tpr, VERSION 2018.6 (single precision)
# Group     0 (         System) has 67927 elements
# Group     1 (        Protein) has  4249 elements
# Group     2 (      Protein-H) has  2144 elements
# Group     3 (        C-alpha) has   263 elements
# Group     4 (       Backbone) has   789 elements
# Group     5 (      MainChain) has  1051 elements
# Group     6 (   MainChain+Cb) has  1299 elements
# Group     7 (    MainChain+H) has  1305 elements
# Group     8 (      SideChain) has  2944 elements
# Group     9 (    SideChain-H) has  1093 elements
# Group    10 (    Prot-Masses) has  4249 elements
# Group    11 (    non-Protein) has 63678 elements
# Group    12 (          Water) has 63546 elements
# Group    13 (            SOL) has 63546 elements
# Group    14 (      non-Water) has  4381 elements
# Group    15 (            Ion) has   132 elements
# Group    16 (              K) has    70 elements
# Group    17 (             CL) has    62 elements
# Group    18 ( Water_and_ions) has 63678 elements
# Reading frame       0 time    0.000
# Precision of abl1_md-fit.xtc is 0.001 (nm)
# Reading frame    9000 time 54000.000
# Dumping frame at t= 57582 ps
#  ->  frame      0 time 57582.000
#
# GROMACS reminds you: "I have noticed a large, negative correlation between having a well-defined mission workload and concern for the Top500. It's almost like LINPACK is what you focus on when you don't know what to focus on." (Jeff Hammond)
#
#              :-) GROMACS - gmx trjconv, 2020.1-Ubuntu-2020.1-1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx trjconv, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /home/baoraa/manuscript/results/3_mtd/2D-profiles/non-phos/3
# Command line:
#   gmx trjconv -s abl1_md.tpr -f abl1_md-fit.xtc -o 24.pdb -dump 55023
#
# Will write pdb: Protein data bank file
# Reading file abl1_md.tpr, VERSION 2018.6 (single precision)
# Reading file abl1_md.tpr, VERSION 2018.6 (single precision)
# Group     0 (         System) has 67927 elements
# Group     1 (        Protein) has  4249 elements
# Group     2 (      Protein-H) has  2144 elements
# Group     3 (        C-alpha) has   263 elements
# Group     4 (       Backbone) has   789 elements
# Group     5 (      MainChain) has  1051 elements
# Group     6 (   MainChain+Cb) has  1299 elements
# Group     7 (    MainChain+H) has  1305 elements
# Group     8 (      SideChain) has  2944 elements
# Group     9 (    SideChain-H) has  1093 elements
# Group    10 (    Prot-Masses) has  4249 elements
# Group    11 (    non-Protein) has 63678 elements
# Group    12 (          Water) has 63546 elements
# Group    13 (            SOL) has 63546 elements
# Group    14 (      non-Water) has  4381 elements
# Group    15 (            Ion) has   132 elements
# Group    16 (              K) has    70 elements
# Group    17 (             CL) has    62 elements
# Group    18 ( Water_and_ions) has 63678 elements
# Reading frame       0 time    0.000
# Precision of abl1_md-fit.xtc is 0.001 (nm)
# Reading frame    9000 time 54000.000
# Dumping frame at t= 55026 ps
#  ->  frame      0 time 55026.000
#
# GROMACS reminds you: "Science... never solves a problem without creating ten more." (George Bernard Shaw)
#
#              :-) GROMACS - gmx trjconv, 2020.1-Ubuntu-2020.1-1 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx trjconv, version 2020.1-Ubuntu-2020.1-1
# Executable:   /usr/bin/gmx
# Data prefix:  /usr
# Working dir:  /home/baoraa/manuscript/results/3_mtd/2D-profiles/non-phos/3
# Command line:
#   gmx trjconv -s abl1_md.tpr -f abl1_md-fit.xtc -o 25.pdb -dump 55210
#
# Will write pdb: Protein data bank file
# Reading file abl1_md.tpr, VERSION 2018.6 (single precision)
# Reading file abl1_md.tpr, VERSION 2018.6 (single precision)
# Group     0 (         System) has 67927 elements
# Group     1 (        Protein) has  4249 elements
# Group     2 (      Protein-H) has  2144 elements
# Group     3 (        C-alpha) has   263 elements
# Group     4 (       Backbone) has   789 elements
# Group     5 (      MainChain) has  1051 elements
# Group     6 (   MainChain+Cb) has  1299 elements
# Group     7 (    MainChain+H) has  1305 elements
# Group     8 (      SideChain) has  2944 elements
# Group     9 (    SideChain-H) has  1093 elements
# Group    10 (    Prot-Masses) has  4249 elements
# Group    11 (    non-Protein) has 63678 elements
# Group    12 (          Water) has 63546 elements
# Group    13 (            SOL) has 63546 elements
# Group    14 (      non-Water) has  4381 elements
# Group    15 (            Ion) has   132 elements
# Group    16 (              K) has    70 elements
# Group    17 (             CL) has    62 elements
# Group    18 ( Water_and_ions) has 63678 elements
# Reading frame       0 time    0.000
# Precision of abl1_md-fit.xtc is 0.001 (nm)
# Reading frame    9000 time 54000.000
# Dumping frame at t= 55212 ps
#  ->  frame      0 time 55212.000
#
# GROMACS reminds you: "It's Coming Right For Us !" (South Park)

# %% [markdown]
# Concatenate all pdb files to make a MFEP trajectory

# %%
# %%bash
# rm mfep-traj-np.pdb
# for i in {1..25}
# do
#  awk '{print}' $i.pdb >> mfep-traj-np.pdb
# done
